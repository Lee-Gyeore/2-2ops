# %%
import pandas as pd
from sklearn.datasets import make_regression
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
df = pd.read_csv('bodyPerformance.csv', sep=',')

# %%
df
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.groupby('gender')['height_cm'].mean()
# Out:
# gender
# F    160.485404
# M    173.257399
# Name: height_cm, dtype: float64

# %% [markdown]
# # 20-30

# %%
TtoT = (df.age >= 20) & (df.age < 30)
df[TtoT]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# 9      28.0      M      185.0      84.60        14.4       81.0     156.0
# 12     27.0      F      156.0      53.90        35.5       69.0     116.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13381  28.0      M      166.5      61.70        22.6       87.0     144.0
# 13382  21.0      M      177.5      74.20        13.7       64.0     133.0
# 13383  25.0      M      170.7      68.86        13.3       60.0     106.0
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
TtoTm = (df.age >= 20) & (df.age < 30)&(df.gender=='M')
df[TtoTm].iloc[:, 2:11].describe()
# Out:
#          height_cm    weight_kg   body fat_%    diastolic     systolic  \
# count  3657.000000  3657.000000  3657.000000  3657.000000  3657.000000
# mean    174.567186    73.780033    18.678895    78.253842   131.558655
# std       5.540061     9.578530     6.054203    10.273895    12.808252
# min     148.000000    38.600000     3.000000    41.000000    92.000000
# 25%     170.900000    67.100000    14.300000    71.000000   122.000000
# 50%     174.400000    72.700000    18.000000    79.000000   131.000000
# 75%     178.400000    79.600000    22.400000    85.000000   141.000000
# max     191.900000   135.780000    78.400000   115.000000   168.000000
#
#          gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm
# count  3657.000000              3657.000000     3657.000000    3657.000000
# mean     43.955261                13.424083       50.273448     222.120345
# std       7.161066                 8.116402        9.609107      25.337048
# ...

# %%
TtoTf = (df.age >= 20) & (df.age < 30)&(df.gender=='F')
df[TtoTf].iloc[:, 2:11].describe()
# Out:
#          height_cm    weight_kg   body fat_%    diastolic     systolic  \
# count  2134.000000  2134.000000  2134.000000  2134.000000  2134.000000
# mean    162.482146    56.566092    27.242305    73.922680   120.401125
# std       5.106411     7.511775     5.601876    10.017244    12.229226
# min     139.900000    31.900000    12.200000     0.000000     0.000000
# 25%     159.100000    51.600000    23.200000    67.000000   112.000000
# 50%     162.400000    55.700000    27.000000    74.000000   120.000000
# 75%     165.975000    60.895000    31.000000    80.000000   128.000000
# max     178.400000   101.100000    48.700000    99.000000   156.000000
#
#          gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm
# count  2134.000000              2134.000000     2134.000000    2134.000000
# mean     26.729888                20.025178       38.989691     168.068885
# std       4.829205                 7.033581       10.967193      22.566097
# ...

# %%
df[TtoT].groupby('gender')[['height_cm','weight_kg','body fat_%','gripForce','sit and bend forward_cm','sit-ups counts','broad jump_cm']].mean()
# Out:
#          height_cm  weight_kg  body fat_%  gripForce  sit and bend forward_cm  \
# gender
# F       162.482146  56.566092   27.242305  26.729888                20.025178
# M       174.567186  73.780033   18.678895  43.955261                13.424083
#
#         sit-ups counts  broad jump_cm
# gender
# F            38.989691     168.068885
# M            50.273448     222.120345

# %%
df[TtoT].iloc[:,5:7].mean()
# Out:
# diastolic     76.657797
# systolic     127.447073
# dtype: float64

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[TtoTm].iloc[:,2:3], bins=30) 
axes2.hist(df[TtoTm].iloc[:,3:4], bins=30)
axes3.hist(df[TtoTm].iloc[:,4:5], bins=30)
axes4.hist(df[TtoTm].iloc[:,5:6], bins=30)
axes4.hist(df[TtoTm].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("20~30 male")
fig.tight_layout()

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[TtoTf].iloc[:,2:3], bins=30) 
axes2.hist(df[TtoTf].iloc[:,3:4], bins=30)
axes3.hist(df[TtoTf].iloc[:,4:5], bins=30)
axes4.hist(df[TtoTf].iloc[:,5:6], bins=30)
axes4.hist(df[TtoTf].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("20~30 female")
fig.tight_layout()

# %%
X = np.array(df[TtoTm].iloc[:,[2,3,5,6]])
#print(X)
y = df[TtoTm].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[TtoTm].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[TtoTm].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  21.263188382902083
# test loss;  21.263188382902083
# 0.41972584301195626

# %%
X = np.array(df[TtoTf].iloc[:,[2,3,5,6]])
#print(X)
y = df[TtoTf].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[TtoTf].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[TtoTf].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  17.747364048853385
# test loss;  17.747364048853385
# 0.43419031224616067

# %% [markdown]
# # 30-40

# %%
TtoF = (df.age >= 30) & (df.age < 40)
df[TtoF]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 2      31.0      M      179.6       78.0        20.1       92.0     152.0
# 3      32.0      M      174.5       71.1        18.4       76.0     147.0
# 5      36.0      F      165.4       55.4        22.0       64.0     119.0
# 7      33.0      M      174.9       77.2        36.9       84.0     137.0
# 22     38.0      M      166.7       67.3        23.2       70.0     111.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13364  38.0      M      175.6       75.4        23.5       80.0     112.0
# 13385  37.0      M      177.5       83.1        29.7       77.0     113.0
# 13387  39.0      M      174.4       70.8        24.3       78.0     132.0
# 13390  39.0      M      177.2       80.5        20.1       78.0     132.0
# 13392  34.0      M      164.0       66.1        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
TtoFm = (df.age >= 30) & (df.age < 40)&(df.gender=='M')
df[TtoFm].iloc[:, 2:11].describe()
# Out:
#          height_cm    weight_kg   body fat_%    diastolic     systolic  \
# count  1945.000000  1945.000000  1945.000000  1945.000000  1945.000000
# mean    174.420154    75.896859    20.421629    81.267455   133.562416
# std       5.519520     9.510458     5.670557    10.059773    13.236232
# min     153.100000    48.900000     4.700000     8.000000    14.000000
# 25%     170.600000    69.600000    16.400000    75.000000   124.000000
# 50%     174.200000    75.000000    20.000000    81.000000   134.000000
# 75%     178.200000    81.100000    23.900000    89.000000   143.000000
# max     193.800000   138.100000    44.800000   120.000000   167.000000
#
#          gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm
# count  1945.000000              1945.000000     1945.000000    1945.000000
# mean     45.918972                13.981198       47.527506     219.455013
# std       7.003973                 8.827382        9.725470      22.368205
# ...

# %%
TtoFf = (df.age >= 30) & (df.age < 40)&(df.gender=='F')
df[TtoFf].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  717.000000  717.000000   717.00000  717.000000  717.000000  717.000000
# mean   161.753138   56.845300    27.21463   75.295955  120.928870   26.591771
# std      5.312627    8.188439     6.14177   11.186187   13.153232    4.617734
# min    147.300000   38.100000    13.40000   45.000000   90.000000    9.100000
# 25%    158.300000   51.900000    22.60000   67.000000  112.000000   23.600000
# 50%    161.800000   55.200000    26.70000   75.000000  120.000000   26.300000
# 75%    165.300000   60.500000    31.20000   82.000000  130.000000   29.300000
# max    179.000000  113.300000    53.50000  156.200000  160.000000   45.500000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               717.000000      717.000000     717.000000
# mean                 18.751911       32.733612     159.362622
# std                   7.373438       11.434665      21.800893
# ...

# %%
df[TtoF].groupby('gender')[['height_cm','weight_kg','body fat_%','gripForce','sit and bend forward_cm','sit-ups counts','broad jump_cm']].mean()
# Out:
#          height_cm  weight_kg  body fat_%  gripForce  sit and bend forward_cm  \
# gender
# F       161.753138  56.845300   27.214630  26.591771                18.751911
# M       174.420154  75.896859   20.421629  45.918972                13.981198
#
#         sit-ups counts  broad jump_cm
# gender
# F            32.733612     159.362622
# M            47.527506     219.455013

# %%
df[TtoF].iloc[:,5:7].mean()
# Out:
# diastolic     79.659053
# systolic     130.159617
# dtype: float64

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[TtoFm].iloc[:,2:3], bins=30) 
axes2.hist(df[TtoFm].iloc[:,3:4], bins=30)
axes3.hist(df[TtoFm].iloc[:,4:5], bins=30)
axes4.hist(df[TtoFm].iloc[:,5:6], bins=30)
axes4.hist(df[TtoFm].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("30~40 male")
fig.tight_layout()

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[TtoFf].iloc[:,2:3], bins=30) 
axes2.hist(df[TtoFf].iloc[:,3:4], bins=30)
axes3.hist(df[TtoFf].iloc[:,4:5], bins=30)
axes4.hist(df[TtoFf].iloc[:,5:6], bins=30)
axes4.hist(df[TtoFf].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("30~40 female")
fig.tight_layout()

# %%
X = np.array(df[TtoFm].iloc[:,[2,3,5,6]])
#print(X)
y = df[TtoFm].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[TtoFm].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[TtoFm].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  18.52638211524776
# test loss;  18.52638211524776
# 0.42354892949725875

# %%
X = np.array(df[TtoFf].iloc[:,[2,3,5,6]])
#print(X)
y = df[TtoFf].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[TtoFf].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[TtoFf].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  18.99916202083895
# test loss;  18.99916202083895
# 0.49562509768438046

# %% [markdown]
# # 40-50

# %%
FtoF = (df.age >= 40) & (df.age < 50)
df[FtoF]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 6      42.0      F      164.5       63.7        32.2       72.0     135.0
# 10     42.0      M      169.2       65.4        19.3       63.0     110.0
# 15     45.0      F      159.0       63.1        30.9       93.0     144.0
# 23     44.0      M      170.0       63.3        12.9       65.0     115.0
# 26     47.0      F      158.3       53.5        29.2       70.0     117.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13353  45.0      M      172.0       60.0        14.2       78.0     145.0
# 13361  41.0      M      178.0       77.0        15.1       84.0     128.0
# 13370  44.0      M      171.3       77.9        22.8       94.0     148.0
# 13374  40.0      F      160.5       68.8        35.1       66.0     109.0
# 13380  42.0      M      172.0       76.3        32.8      100.0     147.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df[FtoF].groupby('gender')[['height_cm','weight_kg','body fat_%','gripForce','sit and bend forward_cm','sit-ups counts','broad jump_cm']].mean()
# Out:
#          height_cm  weight_kg  body fat_%  gripForce  sit and bend forward_cm  \
# gender
# F       160.221470  57.889827   28.222460  26.052104                17.297406
# M       172.788311  74.250452   21.476553  43.269966                12.127534
#
#         sit-ups counts  broad jump_cm
# gender
# F            28.296254     150.848703
# M            40.634812     206.740614

# %%
FtoFm = (df.age >= 40) & (df.age < 50)&(df.gender=='M')
df[FtoFm].iloc[:, 2:11].describe()
# Out:
#          height_cm    weight_kg   body fat_%    diastolic    systolic  \
# count  1172.000000  1172.000000  1172.000000  1172.000000  1172.00000
# mean    172.788311    74.250452    21.476553    83.826280   134.93942
# std       5.305118     9.041601     5.793935     9.929091    13.22681
# min     155.000000    36.500000     6.200000     6.000000    92.00000
# 25%     169.375000    68.600000    17.475000    77.000000   125.00000
# 50%     172.800000    73.550000    21.300000    84.000000   135.00000
# 75%     176.100000    79.200000    24.925000    92.000000   145.00000
# max     191.800000   119.600000    47.400000   112.000000   181.00000
#
#          gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm
# count  1172.000000              1172.000000     1172.000000    1172.000000
# mean     43.269966                12.127534       40.634812     206.740614
# std       6.781626                 9.827564       10.309543      22.879388
# ...

# %%
FtoFf = (df.age >= 40) & (df.age < 50)&(df.gender=='F')
df[FtoFf].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  694.000000  694.000000  694.000000  694.000000  694.000000  694.000000
# mean   160.221470   57.889827   28.222460   76.982709  124.600865   26.052104
# std      4.947264    7.937296    6.565946   11.042734   14.831056    4.454410
# min    144.500000   33.700000    9.400000   42.000000   90.000000    6.700000
# 25%    157.000000   52.700000   24.000000   69.000000  114.000000   23.100000
# 50%    160.050000   56.700000   27.950000   77.000000  123.000000   25.900000
# 75%    163.300000   62.100000   32.500000   84.000000  135.000000   28.700000
# max    175.800000  109.200000   50.600000  105.000000  184.000000   39.200000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               694.000000      694.000000     694.000000
# mean                 17.297406       28.296254     150.848703
# std                   7.744839       11.492368      22.838384
# ...

# %%
df[FtoF].iloc[:,5:7].mean()
# Out:
# diastolic     81.281029
# systolic     131.094319
# dtype: float64

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[FtoFm].iloc[:,2:3], bins=30) 
axes2.hist(df[FtoFm].iloc[:,3:4], bins=30)
axes3.hist(df[FtoFm].iloc[:,4:5], bins=30)
axes4.hist(df[FtoFm].iloc[:,5:6], bins=30)
axes4.hist(df[FtoFm].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("40~50 male")
fig.tight_layout()

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[FtoFf].iloc[:,2:3], bins=30) 
axes2.hist(df[FtoFf].iloc[:,3:4], bins=30)
axes3.hist(df[FtoFf].iloc[:,4:5], bins=30)
axes4.hist(df[FtoFf].iloc[:,5:6], bins=30)
axes4.hist(df[FtoFf].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("40~50 female")
fig.tight_layout()

# %%
X = np.array(df[FtoFm].iloc[:,[2,3,5,6]])
#print(X)
y = df[FtoFm].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[FtoFm].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[FtoFm].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  19.411966441935256
# test loss;  19.411966441935256
# 0.42124722825541294

# %%
X = np.array(df[FtoFf].iloc[:,[2,3,5,6]])
#print(X)
y = df[FtoFf].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[FtoFf].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[FtoFf].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  18.87031751632698
# test loss;  18.87031751632698
# 0.5616602743313666

# %% [markdown]
# # 50-60

# %%
FtoS = (df.age >= 50) & (df.age < 60)
df[FtoS]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 8      54.0      M      166.8      67.50        27.6       85.0     165.0
# 11     57.0      F      153.0      49.00        20.9       69.0     106.0
# 21     59.0      F      155.9      62.70        30.2       76.0     143.0
# 29     50.0      F      159.8      57.10        24.4       63.0     103.0
# 41     52.0      M      173.6      84.90        30.3       93.0     144.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13369  54.0      M      164.6      64.50        21.9       78.0     120.0
# 13371  54.0      M      164.7      67.50        15.2       83.0     139.0
# 13377  53.0      M      170.2      56.90        13.3       70.0     120.0
# 13378  51.0      M      179.8      78.56        21.9       94.0     156.0
# 13379  59.0      M      169.3      65.20        23.8       75.0     126.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df[FtoS].groupby('gender')[['height_cm','weight_kg','body fat_%','gripForce','sit and bend forward_cm','sit-ups counts','broad jump_cm']].mean()
# Out:
#          height_cm  weight_kg  body fat_%  gripForce  sit and bend forward_cm  \
# gender
# F       157.487101  57.230154   30.783835  24.218580                17.785041
# M       170.019621  70.899955   21.995336  40.391973                12.539019
#
#         sit-ups counts  broad jump_cm
# gender
# F            20.482130     134.544379
# M            35.616499     189.130435

# %%
FtoSm = (df.age >= 50) & (df.age < 60)&(df.gender=='M')
df[FtoSm].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  897.000000  897.000000  897.000000  897.000000  897.000000  897.000000
# mean   170.019621   70.899955   21.995336   83.505017  137.061315   40.391973
# std      5.308403    8.601636    5.091739    9.860423   14.023324    5.982952
# min    145.800000   48.420000    4.900000   51.000000   91.000000   19.900000
# 25%    166.300000   65.300000   18.600000   77.000000  127.000000   36.600000
# 50%    170.000000   70.560000   21.900000   84.000000  138.000000   40.400000
# 75%    173.700000   75.600000   24.900000   91.000000  148.000000   43.900000
# max    186.600000  104.500000   45.800000  118.000000  193.000000   62.900000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               897.000000      897.000000     897.000000
# mean                 12.539019       35.616499     189.130435
# std                   7.581678        9.723526      23.113746
# ...

# %%
FtoSf = (df.age >= 50) & (df.age < 60)&(df.gender=='F')
df[FtoSf].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  845.000000  845.000000  845.000000  845.000000  845.000000  845.000000
# mean   157.487101   57.230154   30.783835   77.653254  129.265089   24.218580
# std      5.191397    7.396053    6.230153   10.480709   15.381970    4.050709
# min    125.000000   34.400000    3.500000   40.000000   82.000000   10.400000
# 25%    154.100000   52.300000   26.600000   70.000000  119.000000   21.600000
# 50%    157.100000   56.400000   31.200000   78.000000  128.000000   24.200000
# 75%    161.000000   61.300000   35.000000   85.000000  140.000000   27.100000
# max    172.000000   95.100000   49.800000  106.000000  177.000000   37.400000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               845.000000      845.000000     845.000000
# mean                 17.785041       20.482130     134.544379
# std                   6.486738       10.533738      22.556448
# ...

# %%
df[FtoS].iloc[:,5:7].mean()
# Out:
# diastolic     80.666475
# systolic     133.279564
# dtype: float64

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[FtoSm].iloc[:,2:3], bins=30) 
axes2.hist(df[FtoSm].iloc[:,3:4], bins=30)
axes3.hist(df[FtoSm].iloc[:,4:5], bins=30)
axes4.hist(df[FtoSm].iloc[:,5:6], bins=30)
axes4.hist(df[FtoSm].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("50~60 male")
fig.tight_layout()

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[FtoSf].iloc[:,2:3], bins=30) 
axes2.hist(df[FtoSf].iloc[:,3:4], bins=30)
axes3.hist(df[FtoSf].iloc[:,4:5], bins=30)
axes4.hist(df[FtoSf].iloc[:,5:6], bins=30)
axes4.hist(df[FtoSf].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("50~60 female")
fig.tight_layout()

# %%
X = np.array(df[FtoSm].iloc[:,[2,3,5,6]])
#print(X)
y = df[FtoSm].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[FtoSm].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[FtoSm].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  14.011468503810743
# test loss;  14.011468503810743
# 0.45895194809881024

# %%
X = np.array(df[FtoSf].iloc[:,[2,3,5,6]])
#print(X)
y = df[FtoSf].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[FtoSf].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[FtoSf].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  17.566891031625005
# test loss;  17.566891031625005
# 0.5468815543312828

# %% [markdown]
# # 60-

# %%
StoA = (df.age >= 60)
df[StoA]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 25     62.0      M      169.0       70.7        30.5       96.0     146.0
# 65     63.0      M      166.6       75.5        31.6       62.0     122.0
# 73     60.0      M      175.1       66.5        17.3       85.0     125.0
# 79     60.0      F      158.6       62.7        34.6       80.0     137.0
# 136    61.0      F      153.2       62.2        37.0       71.0     111.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13373  64.0      M      165.6       52.1        11.0       71.0     119.0
# 13376  60.0      M      173.0       71.3        18.3       93.0     154.0
# 13384  64.0      F      152.4       55.9        33.1       87.0     158.0
# 13386  62.0      F      156.2       40.0        20.2       61.0     115.0
# 13391  64.0      F      146.1       57.7        40.4       68.0     121.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df[StoA].groupby('gender')[['height_cm','weight_kg','body fat_%','gripForce','sit and bend forward_cm','sit-ups counts','broad jump_cm']].mean()
# Out:
#          height_cm  weight_kg  body fat_%  gripForce  sit and bend forward_cm  \
# gender
# F       155.908396  56.554701   31.857760  23.370709                17.897761
# M       168.738065  69.034774   22.618029  38.790176                11.490766
#
#         sit-ups counts  broad jump_cm
# gender
# F            15.927239     119.371269
# M            30.951005     175.927136

# %%
StoAm = (df.age >= 60)&(df.gender=='M')
df[StoAm].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  796.000000  796.000000  796.000000  796.000000  796.000000  796.000000
# mean   168.738065   69.034774   22.618029   82.462312  140.070352   38.790176
# std      5.178181    8.066874    5.369943    9.930062   14.844013    5.930773
# min    153.100000   39.100000    3.500000   42.000000   97.000000   12.200000
# 25%    165.375000   64.000000   19.400000   77.000000  129.000000   34.975000
# 50%    168.600000   68.600000   22.600000   83.000000  141.000000   39.100000
# 75%    172.000000   74.025000   25.900000   89.000000  152.000000   42.600000
# max    190.900000  102.200000   41.000000  126.000000  201.000000   59.100000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               796.000000      796.000000     796.000000
# mean                 11.490766       30.951005     175.927136
# std                   7.183512        8.802307      20.528544
# ...

# %%
StoAf = (df.age >= 60)&(df.gender=='F')
df[StoAf].iloc[:, 2:11].describe()
# Out:
#         height_cm   weight_kg  body fat_%   diastolic    systolic   gripForce  \
# count  536.000000  536.000000   536.00000  536.000000  536.000000  536.000000
# mean   155.908396   56.554701    31.85776   77.457090  133.233209   23.370709
# std      4.944725    7.255778     5.98798   10.926861   16.118246    3.947707
# min    140.500000   26.300000    11.60000   47.000000   98.000000   10.200000
# 25%    152.675000   51.575000    27.70000   69.000000  120.750000   20.900000
# 50%    155.700000   56.130000    32.20000   77.000000  133.000000   23.200000
# 75%    159.200000   60.700000    35.75000   86.000000  146.000000   25.800000
# max    175.100000   90.300000    50.30000  113.000000  179.000000   40.200000
#
#        sit and bend forward_cm  sit-ups counts  broad jump_cm
# count               536.000000      536.000000     536.000000
# mean                 17.897761       15.927239     119.371269
# std                   6.716538       10.236289      25.195502
# ...

# %%
df[StoA].iloc[:,5:7].mean()
# Out:
# diastolic     80.448198
# systolic     137.319069
# dtype: float64

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[StoAm].iloc[:,2:3], bins=30) 
axes2.hist(df[StoAm].iloc[:,3:4], bins=30)
axes3.hist(df[StoAm].iloc[:,4:5], bins=30)
axes4.hist(df[StoAm].iloc[:,5:6], bins=30)
axes4.hist(df[StoAm].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("60~ male")
fig.tight_layout()

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(2, 2, 1) 
axes2 = fig.add_subplot(2, 2, 2) 
axes3 = fig.add_subplot(2, 2, 3) 
axes4 = fig.add_subplot(2, 2, 4) 
axes1.hist(df[StoAf].iloc[:,2:3], bins=30) 
axes2.hist(df[StoAf].iloc[:,3:4], bins=30)
axes3.hist(df[StoAf].iloc[:,4:5], bins=30)
axes4.hist(df[StoAf].iloc[:,5:6], bins=30)
axes4.hist(df[StoAf].iloc[:,6:7], bins=30)
axes1.set_title("height") 
axes2.set_title("weight")
axes3.set_title("body fat") 
axes4.set_title("blood pressure")
fig.suptitle("60~ female")
fig.tight_layout()

# %%
X = np.array(df[StoAm].iloc[:,[2,3,5,6]])
#print(X)
y = df[StoAm].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[StoAm].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[StoAm].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  16.56966212829438
# test loss;  16.56966212829438
# 0.42466577951688445

# %%
X = np.array(df[StoAf].iloc[:,[2,3,5,6]])
#print(X)
y = df[StoAf].iloc[:,4] # column 3
lr = LinearRegression()
lr.fit(X, y)
#print(lr.coef_)

train_y = lr.predict(X)
train_loss = mean_squared_error(y, train_y)
print('train loss; ', train_loss)


test_X = np.array(df[StoAf].iloc[:,[2,3,5,6]])
pred_y = lr.predict(test_X)
test_y = df[StoAf].iloc[:,4] # column 3

test_loss = mean_squared_error(test_y, pred_y)

print('test loss; ', test_loss)

plt.scatter(test_y, pred_y)
plt.plot([0,np.max(pred_y)],[0,np.max(pred_y)], color='red')

from sklearn.metrics import r2_score
r2 = r2_score(test_y, pred_y)
print(r2)
# Out:
# train loss;  19.178286261432046
# test loss;  19.178286261432046
# 0.4641291266627936
